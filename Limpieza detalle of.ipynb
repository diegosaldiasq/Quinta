# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Detalle_of_cln.xlsx')

# %%
df.head()
# Out:
#    # Orden Fecha de Creación Fecha de Vencimiento   Turno Estatus de la Orden  \
# 0    16306        2021-01-04           2021-01-04       0                   C
# 1    16306        2021-01-04           2021-01-04       0                   C
# 2    16306        2021-01-04           2021-01-04       0                   C
# 3    16306        2021-01-04           2021-01-04       0                   C
# 4    16311        2021-01-29           2021-02-01  INSUMO                   P
#
#    Artículo a Producir   Descripción del Artículo Insumo Pasteleria  Grupo  \
# 0               393054             SUB RED VELVET      Y          N    128
# 1               393054             SUB RED VELVET      Y          N    128
# 2               393054             SUB RED VELVET      Y          N    128
# 3               393054             SUB RED VELVET      Y          N    128
# 4               362113  BIZCOCHO RED VELVET 1 X 4      Y          N    128
#
# ...

# %%
df.columns
# Out:
# Index(['# Orden', 'Fecha de Creación', 'Fecha de Vencimiento', 'Turno',
#        'Estatus de la Orden', 'Artículo a Producir',
#        'Descripción del Artículo', 'Insumo', 'Pasteleria', 'Grupo', 'Almacén',
#        'Descripción Almacén', 'Cantidad Planificada', 'Cantidad Completada',
#        'Productividad', 'Insumo.1', 'Nombre del Insumo', 'Cantidad Base',
#        'Cantidad Planificada.1', 'Cantidad Entregada', 'SobreConsumo',
#        'Costo'],
#       dtype='object')

# %%
biz_bl = df['Insumo.1'] == 403344
Data_cln = df[biz_bl]

# %%
Data_cln
# Out:
#         # Orden Fecha de Creación Fecha de Vencimiento Turno  \
# 382       16373        2021-06-14           2021-06-15     0
# 390       16376        2021-06-14           2021-06-15     0
# 564    50008039        2021-01-01           2021-01-04     0
# 566    50008040        2021-01-01           2021-01-04     0
# 574    50008043        2021-01-01           2021-01-04     0
# ...         ...               ...                  ...   ...
# 68754  50018210        2021-08-18           2021-08-20     0
# 68760  50018212        2021-08-18           2021-08-20     0
# 68771  50018216        2021-08-18           2021-08-20     0
# 68773  50018217        2021-08-18           2021-08-20     0
# 68779  50018219        2021-08-18           2021-08-20     0
#
#       Estatus de la Orden  Artículo a Producir  \
# 382                     C               393045
# 390                     C               393119
# 564                     L               393045
# ...

# %%
Data_cln.to_excel('Detalle_lim_ch.xlsx')
